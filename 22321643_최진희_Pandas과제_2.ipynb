# %% [markdown]
# <a href="https://colab.research.google.com/github/hisjeans/data-analysis-ml/blob/main/22321643_%E1%84%8E%E1%85%AC%E1%84%8C%E1%85%B5%E1%86%AB%E1%84%92%E1%85%B4_Pandas%E1%84%80%E1%85%AA%E1%84%8C%E1%85%A6_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas 과제

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1) 타이타닉 데이터를 데이터프레임으로 불러오기
# ### A. 과제게시판 - 타이타닉데이터 다운로드 및 데이터 불러오기

# %%
df = pd.read_csv("/content/drive/MyDrive/2025_2학기_데이터분석과머신러닝/타이타닉데이터셋.csv")

# %% [markdown]
# ## 2) 타이타닉 데이터 프레임에 대해 요약 기능 사용하기

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %% [markdown]
# ### 타이타닉 데이터 컬럼 설명
# - PassangerID : 승객 ID
# - Survived : 생존 여부, 0=사망, 1=생존
# - Pclass : 티켓의 등급 (1=1st, 2=2nd, 3=3rd)
# - Name : 승객의 이름
# - Sex : 성별
# - Age : 연력
# - SibSp : 타이타닉호에 탑승한 형제/배우자의 수
# - Parch : 타이타닉호에 탑승한 부모/자녀 수
# - Ticket : 티켓 번호
# - Fare : 승객 요금
# - Cabin : 객실 번호
# - Embarked : 탑승 위치

# %%
del df['Cabin']
df = df.dropna()
df = df.reset_index(drop=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 326         1301         1       3
# 327         1303         1       1
# 328         1304         1       3
# 329         1306         1       1
# 330         1307         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 3                                   Wirz, Mr. Albert    male  27.0      0
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                               ...     ...   ...    ...
# ...

# %% [markdown]
# ## 3) 타이타닉 데이터 프레임 Human_classfi 컬럼 추가하기
# - 남자이며, 19세 미만은 [Child_m]으로 설정
# - 여자이며, 19세 미만은 [Child_f]으로 설정
# - 남자이며, 19세 이상은 [Mr]으로 설정
# - 여자이며, 19세 미만은 [Ms]으로 설정

# %%
df.loc[(df['Sex'] == 'male')&(df['Age']<19), 'Human_classfi'] = 'Child_m'
df.loc[(df['Sex'] == 'female')&(df['Age']<19), 'Human_classfi'] = 'Child_f'
df.loc[(df['Sex']=='male')&(df['Age']>=19),'Human_classfi']='Mr'
df.loc[(df['Sex']=='female')&(df['Age']>=19),'Human_classfi']='Ms'
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 326         1301         1       3
# 327         1303         1       1
# 328         1304         1       3
# 329         1306         1       1
# 330         1307         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 3                                   Wirz, Mr. Albert    male  27.0      0
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                               ...     ...   ...    ...
# ...

# %% [markdown]
# ## 4) 아래의 데이터 프레임을 타이타닉 데이터 프레임에 조인하기

# %%
data_dict = {
    "Human_classfi" : ['Child_m', 'Child_f', 'Mr','Ms'],
    "HC_DES" : ['19세 미만의 남성', '19세 미만의 여성','19세 이상의 남성','19세 이상의 여성']
}
des_df = pd.DataFrame(data_dict)
des_df
# Out:
#   Human_classfi      HC_DES
# 0       Child_m  19세 미만의 남성
# 1       Child_f  19세 미만의 여성
# 2            Mr  19세 이상의 남성
# 3            Ms  19세 이상의 여성

# %%
df=df.merge(des_df, how='left', on='Human_classfi')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 326         1301         1       3
# 327         1303         1       1
# 328         1304         1       3
# 329         1306         1       1
# 330         1307         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 3                                   Wirz, Mr. Albert    male  27.0      0
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                               ...     ...   ...    ...
# ...

# %% [markdown]
# ## 5) Human_classfi 별 생존자 수 확인하기

# %%
df.groupby('Human_classfi')['Survived'].sum()
# Out:
# Human_classfi
# Child_f     25
# Child_m      0
# Mr           0
# Ms         102
# Name: Survived, dtype: int64
